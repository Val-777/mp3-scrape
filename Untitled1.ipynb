# %%
from requests.exceptions import ConnectionError
from time import time, localtime, strftime
from datetime import timedelta, datetime
from pytz import timezone
import codecs

from bs4 import BeautifulSoup
import requests
from requests.exceptions import Timeout
from requests.packages.urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

import textwrap as tw

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

url = 'http://tut-audio.su'

page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

letter_links = []
for i in range(2):
    for link in soup.find_all("div", "letters")[i].find_all('a'):
        letter_links.append(link.get('href'))
        
url_letter = url + letter_links[0]

page = requests.get(url_letter)

soup = BeautifulSoup(page.content, 'html.parser')
# print(soup.prettify())
# print(url_letter)
                       
categories = []
while True:
    for category in soup.find_all("li", "artist_num"):
        art = {'name': category.find('h2').find('b').get_text(), 'url': category.find('a').get('href')}
        categories.append(art)

    if soup.find("a", text="Next"):
        next_link = soup.find("a", text="Next").get('href')
        page = requests.get(url + next_link)
        soup = BeautifulSoup(page.content, 'html.parser')
        print(next_link)
    else:
        break
        
cats = categories[:2]
cats

def write_to_log(messages):
    for message in messages:
        print(message[:-1])
    file = codecs.open('logfile.txt','a', 'utf-8')
    for message in messages:
        file.writelines(message)
    file.close()
    
SEPARATOR = '-------------------------------------------------------------------------------------------\n'

def unescape(s):
    s = s.replace("&lt;", "<")
    s = s.replace("&gt;", ">")
    s = s.replace("&quot;", '"')
    s = s.replace("&apos;", "'")
    s = s.replace("&#39;", "'")
    s = s.replace("&amp;", "&")
    return s
# Out:
# /mus-0/1
# /mus-0/2

# %%
import sqlite3
from sqlite3 import Error
 
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        conn.close()

database = 'mp3database{}.db'.format(79)

create_connection("C:/Users/val31/Desktop/Projects/mp3scrape/{}".format(database))

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy import Column, Integer, String, Boolean, ForeignKey, DateTime, func
from sqlalchemy.orm import relationship

class Artist(Base):
    __tablename__ = 'artist'
    
    id = Column(Integer, primary_key=True)
    name = Column(String(250), nullable=False)
    created_date = Column(DateTime, default=datetime.now(timezone('Europe/Berlin')))
    albums = relationship('Album', back_populates="artist")
#     tracks = relationship('Track', back_populates="artist")
    
    def __repr__(self):
        return "<Artist({})>".format(self.name)
                       
                       
class Album(Base):
    __tablename__ = 'album'
    
    id = Column(Integer, primary_key=True)
    name = Column(String(250))
    year = Column(Integer)
    url = Column(String)
    cover_url = Column(String)
    number_of_tracks = Column(Integer)
    live_tracks = Column(Integer)
    genre = Column(String)
    created_date = Column(DateTime, default=datetime.now(timezone('Europe/Berlin')))
    
    artist_id = Column(Integer, ForeignKey('artist.id'))  
    artist = relationship("Artist", back_populates="albums", foreign_keys=[artist_id])
    
    tracks = relationship('Track', back_populates="album") # , foreign_keys=[track.id])

    def verbose(self):
        print('Name: {}'.format(self.name))
        print('Artist: {}'.format(self.artist.name))
        print('Genre: {}'.format(self.genre))
        print('Year: {}'.format(self.year))
        print('Number of tracks: {}'.format(self.number_of_tracks))
        print('Number of live tracks: {}'.format(self.live_tracks))
        print('URL: {}'.format(self.url))
        print('Cover URL: {}'.format(self.cover_url))
        print('ID: {}'.format(self.id))
        print('Created: {}'.format(self.created_date))
    
    def __repr__(self):
        if self.year:
            return "<Album({} by {} from {})>".format(self.name, self.artist.name, self.year)
        else:
            return "<Album({} by {})>".format(self.name, self.artist.name)
    

class Track(Base):
    __tablename__ = 'track'
    
    id = Column(Integer, primary_key=True)
    name = Column(String)
    year = Column(Integer)
    url = Column(String)
    number = Column(Integer)
    live = Column(Boolean)
    created_date = Column(DateTime, default=datetime.now(timezone('Europe/Berlin')))
    
#     artist_id = Column(Integer, ForeignKey('artist.id'))  
#     artist = relationship("Artist", back_populates="tracks", foreign_keys=[artist_id])
    
    album_id = Column(Integer, ForeignKey('album.id'))  
    album = relationship("Album", back_populates="tracks") # , foreign_keys=[album_id])

    def verbose(self):
        print('Name: {}'.format(self.name))
        #print('Artist: {}'.format(self.artist.name))
        print('Year: {}'.format(self.year))
        print('Number: {} / {}'.format(self.number, self.album.number_of_tracks))
        print('URL: {}'.format(self.url))
        print('ID: {}'.format(self.id))
        print('Created: {}'.format(self.created_date))
        if live:
            status = 'Live'
        else:
            status = 'Missing'
        print('Status: {}'.format(status))
    
    def __repr__(self):
        return "<Track({} by {})>".format(self.name, self.album.artist.name)


engine = create_engine('sqlite:///{}'.format(database, echo=False))
Base.metadata.create_all(engine)
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

def collect_album_info(album_soup):
    url = 'http://tut-audio.su'
    album_dict = {}
    album_dict['name'] = unescape(album_soup.find(id="titlealb").get_text()[:-14])
    album_dict['year'] = album_soup.find(id="dopinfoalb").find('p').find('b').get_text()
    if album_dict['year']:
        album_dict['year'] = int(album_dict['year'])
    album_dict['cover_url'] = url + album_soup.find(id="imagesalb").get('src')
    t = album_soup.find_all("div", "player")[0]
    artist, _ = t['data-title'].split(' — ')
    artist = unescape(artist)
    album_dict['url'] = url + album_url
    return album_dict, artist

def create_album(album_dict):
    db_album = Album(**album_dict)
    session.add(db_album)
    session.commit()
    write_to_log([tw.indent('This album has been added to the data base:\n', '   '),
                tw.indent('Artist: {}\n'.format(db_album.artist.name), '     '),
                tw.indent('Album name: {}\n'.format(db_album.name), '     '),
                tw.indent('Year: {}\n'.format(db_album.year), '     '),
                tw.indent('Cover: {}\n'.format(db_album.cover_url), '     ')])
    return db_album

def get_tracks(album, links):
    track_num = 1
    missing_tracks_from_album = 0
    live_tracks = 0
    total_tracks = len(links)
#     missing_tracks = []
    timeouts = []
#     artist = session.query(Artist).filter_by(name=album.artist).first()
    for link in links:
        track = {}
        _, track['name'] = link['data-title'].split(' — ')
#         track['artist'] = unescape(track['artist'])
        track['year'] = album.year
        track['album'] = album
#         track['artist'] = artist
        track['name'] = unescape(track['name'])
        track['number'] = track_num
        log_track_num = '{}/{}'.format(track_num, total_tracks)
        track['url'] = ''
        write_to_log([tw.indent('{} {}\n'.format(log_track_num, track['name']), '        ')])
        tr_page = ''
        
        t0 = time()
        try:
            tr_page = requests_retry_session().head(
                url + link['data-mp3url'],
            )
        except Exception as x:
            message = 'Exception: {}'.format(x.__class__.__name__)
            track['live'] = False
        else:
            message = 'Status code: {}'.format(tr_page.status_code)
            if tr_page.status_code is 524:
                timeouts.append(url + link['data-mp3url'])
                write_to_log([tw.indent('Timeout!\n', '        ')])
            if tr_page.status_code not in [200, 524]:
                missing_tracks_from_album += 1
                write_to_log([tw.indent('Track is missing!\n', '        ')])
            track['live'] = False
        finally:
            t1 = time()
            elapsed = timedelta(seconds=t1 - t0)
            write_to_log([tw.indent('{} and took {}'.format(message, elapsed), '        ')])

        if tr_page and tr_page.status_code == 200:
            track['url'] = url + link['data-mp3url']
            track['live'] = True
            live_tracks += 1
        new_track = Track(**track)
        session.add(new_track)
        session.commit()
        write_to_log([tw.indent('{}\n'.format(url + link['data-mp3url']), '        ')])

        track_num += 1
    write_to_log([SEPARATOR])
    return missing_tracks_from_album, live_tracks, timeouts

def retrieve_or_create(artist_name):
    db_artist = session.query(Artist).filter_by(name=artist_name).first()
    if not db_artist:
        db_artist = Artist(name=artist_name)
        session.add(db_artist)
        session.commit()
        write_to_log([tw.indent('New Artist {} added to data base!\n'.format(db_artist.name), '   ')])
        added = True
    else:
        write_to_log([tw.indent('Artist {} retrieved from data base!\n'.format(db_artist.name), '   ')])
        added = False
    return db_artist, added
# Out:
# 2.6.0

# %%
file = open('logfile.txt','w')
file.close()
start = time()
write_to_log([('Started at: {}\n'.format(strftime("%a, %d %b %Y %H:%M:%S +0000", localtime(start))))])
# cats = [{'name': '0800', 'url': '/music-file/0800'}, ]
cats = [{'name': '007-man', 'url': '/music-file/007-man'}, ]
# cats = [{'name': '08001', 'url': '/music-file/08001'}, ]
# cats = [{'name': '007-band', 'url': '/music-file/007-band'}, ]
alben = []
artists_added = 0
albums_added = 0
tracks_added = 0
missing_tracks = 0
connection_errors = 0
timeouts = []
for category in cats:
    page=requests.get(url + category['url'])
    if page.status_code == 404:
        write_to_log([SEPARATOR, 'Category {} has no music\n'.format(category['name']), SEPARATOR])
    elif page.status_code == 200:
        write_to_log(['Category {} has music!\n'.format(category['name'])])
        album_num = 0
        for i in range(1, 10):
            write_to_log([tw.indent('Try No. {}\n'.format(i), ' ')])
            soup = BeautifulSoup(page.content, 'html.parser')
            while True:
                tracks = soup.find_all('div', 'player')        
                for track in tracks:
                    try:
                        album_url = track.find('div', 'track-info').find('div').find('a').get('href')
                        if album_url not in alben:
                            try:
                                al_page=requests.get(url + album_url)
                            except (ConnectionError or ConnectionResetError) as e:
                                write_to_log([e])
                                connection_errors += 1
                                al_page=requests.get(url + album_url)
                            if al_page.status_code == 200:
                                alben.append(album_url)
                                album_num += 1
                                write_to_log([tw.indent('Found: {} ({}) \n'.format(url + album_url, album_num), '  ')])
                                album_soup = BeautifulSoup(al_page.content, 'html.parser')
                                links_to_tracks = album_soup.find_all("div", "player")

                                album_dict, artist_name = collect_album_info(album_soup)                                                             
                                album_dict['artist'], added = retrieve_or_create(artist_name)
                                if added:
                                    artists_added += 1
                                
                                db_album = session.query(Album).filter_by(name=album_dict['name']).first()
                                
                                if db_album and (db_album.url == (url + album_url)):
                                    write_to_log([tw.indent('The album {} by {} is already in the data base!\n'.format(album_dict['name'], db_album.artist.name), '   ')])
                                    write_to_log([tw.indent(SEPARATOR, '   ')])
                                    album_num -= 1
                                else:
                                    album = create_album(album_dict)
                                    missing, live, timeouts_alb = get_tracks(album, links_to_tracks)
                                    print('Missing: {}, Live: {}, Timeouts: {}\n'.format(missing, live, timeouts_alb))
                                    album.live_tracks = live
                                    album.number_of_tracks = live + missing
                                    session.commit()
                                    missing_tracks += missing
                                    tracks_added += live
                                    timeouts += timeouts_alb
                    except AttributeError as e:
                        print(e)
                        print(track)

                if soup.find("a", text="Next"):
                    next_link = soup.find("a", text="Next").get('href')
                    al_page = requests.get(url + next_link)
                    soup = BeautifulSoup(al_page.content, 'html.parser')
                    write_to_log(['  {}\n'.format(next_link)])
                else:
                    break
        write_to_log([SEPARATOR,'Added {} Albums to the database of {}\n'.format(album_num, category['name']), SEPARATOR])
        albums_added += album_num
    else:
        write_to_log(['Category: {}, status code: {}\n'.format(category['name'], page.status_code)])
        
end = time()
endtime = strftime("%a, %d %b %Y %H:%M:%S +0000", localtime(end))
elapsed = timedelta(seconds=end - start)
write_to_log(['Ended at {}, so needed {}\n'.format(endtime, elapsed)])
write_to_log(['Artists added to data base: {}\n'.format(artists_added)])
write_to_log(['Albums added to data base: {}\n'.format(albums_added)])
write_to_log(['Tracks added to data base: {}\n'.format(tracks_added)])
write_to_log(['Missing tracks: {}\n'.format(missing_tracks)])
write_to_log(['Connection errors: {}\n'.format(connection_errors)])
write_to_log(['Timeouts: {}\n'.format(len(timeouts))])
write_to_log(['{}\n'.format(timeout_link) for timeout_link in timeouts])
# Out:
# Started at: Mon, 05 Feb 2018 21:38:29 +0000
# Category 007-man has music!
#  Try No. 1
#   Found: http://tut-audio.su/mp3-album-james-bond-007-ultimate-collection-vol-1-download-5387450.html (1)
#    New Artist High School Music Band added to data base!
#    This album has been added to the data base:
#      Artist: High School Music Band
#      Album name: James Bond 007 Ultimate Collection, Vol. 1
#      Year: 2012
#      Cover: http://tut-audio.su/alb-mus/5387450-460x460/james-bond-007-ultimate-collection-vol-1.jpg
#         1/22 Goldeneye
#         Status code: 200 and took 0:00:00.53903
#         http://tut-audio.su/download-music/9889076/high-school-music-band-goldeneye.mp3
#         2/22 You Only Live Twice
#         Status code: 200 and took 0:00:00.46086
#         http://tut-audio.su/download-music/9889077/high-school-music-band-you-only-live-twice.mp3
#         3/22 The Man With the Golden Gun
#         Status code: 200 and took 0:00:00.41827
#         http://tut-audio.su/download-music/9889078/high-school-music-band-the-man-with-the-golden-gun.mp3
#         4/22 A View to a Kill
#         Status code: 200 and took 0:00:00.69524
#         http://tut-audio.su/download-music/9889079/high-school-music-band-a-view-to-a-kill.mp3
#         5/22 The World Is Not Enough
#         Status code: 200 and took 0:00:00.75644
#         http://tut-audio.su/download-music/9889080/high-school-music-band-the-world-is-not-enough.mp3
#         6/22 Never Say Never Again
#         Status code: 200 and took 0:00:00.47770
#         http://tut-audio.su/download-music/9889081/high-school-music-band-never-say-never-again.mp3
#         7/22 The Living Daylights
#         Status code: 200 and took 0:00:00.44031
#         http://tut-audio.su/download-music/9889082/high-school-music-band-the-living-daylights.mp3
#         8/22 Mr. Kiss Kiss Bang Bang
#         Status code: 200 and took 0:00:00.39127
#         http://tut-audio.su/download-music/9889083/high-school-music-band-mr-kiss-kiss-bang-bang.mp3
#         9/22 All Time High (Octopussy)
#         Status code: 200 and took 0:00:00.39477
#         http://tut-audio.su/download-music/9889084/high-school-music-band-all-time-high-octopussy.mp3
#         10/22 Thunderball
#         Status code: 200 and took 0:00:00.44857
#         http://tut-audio.su/download-music/9889085/high-school-music-band-thunderball.mp3
#         11/22 Goldfinger
#         Status code: 200 and took 0:00:00.51190
#         http://tut-audio.su/download-music/9889086/high-school-music-band-goldfinger.mp3
#         12/22 Moonraker
#         Status code: 200 and took 0:00:00.73952
#         http://tut-audio.su/download-music/9889087/high-school-music-band-moonraker.mp3
#         13/22 Theme from Dr. No
#         Status code: 200 and took 0:00:00.34229
#         http://tut-audio.su/download-music/9889088/high-school-music-band-theme-from-dr-no.mp3
#         14/22 Live & Let Die
#         Status code: 200 and took 0:00:01.24974
#         http://tut-audio.su/download-music/9889089/high-school-music-band-live-let-die.mp3
#         15/22 Licence to Kill
#         Status code: 200 and took 0:00:00.83972
#         http://tut-audio.su/download-music/9889090/high-school-music-band-licence-to-kill.mp3
#         16/22 Diamonds Are Forever
#         Status code: 200 and took 0:00:00.98822
#         http://tut-audio.su/download-music/9889091/high-school-music-band-diamonds-are-forever.mp3
#         17/22 Ohmss
#         Status code: 200 and took 0:00:00.62138
#         http://tut-audio.su/download-music/9889092/high-school-music-band-ohmss.mp3
#         18/22 Casino Royale
#         Status code: 200 and took 0:00:00.78078
#         http://tut-audio.su/download-music/9889093/high-school-music-band-casino-royale.mp3
#         19/22 Nobody Does It Better
#         Status code: 200 and took 0:00:00.54858
#         http://tut-audio.su/download-music/9889094/high-school-music-band-nobody-does-it-better.mp3
#         20/22 From Russia With Love
#         Status code: 200 and took 0:00:01.77942
#         http://tut-audio.su/download-music/9889095/high-school-music-band-from-russia-with-love.mp3
#         21/22 For Your Eyes Only
#         Status code: 200 and took 0:00:00.51219
#         http://tut-audio.su/download-music/9889096/high-school-music-band-for-your-eyes-only.mp3
#         22/22 Tomorrow Never Dies
#         Status code: 200 and took 0:00:00.41874
#         http://tut-audio.su/download-music/9889097/high-school-music-band-tomorrow-never-dies.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 22, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-reggaeton-freestyle-mix-tape-vol-007-download-5323164.html (2)
#    New Artist DJ Mango Man added to data base!
#    This album has been added to the data base:
#      Artist: DJ Mango Man
#      Album name: Reggaeton Freestyle Mix Tape (Vol. 007)
#      Year: 2007
#      Cover: http://tut-audio.su/alb-mus/5323164-460x460/reggaeton-freestyle-mix-tape-vol-007.jpg
#         1/13 Rhythm Is Dancer
#         Status code: 200 and took 0:00:00.52159
#         http://tut-audio.su/download-music/9179076/dj-mango-man-rhythm-is-dancer.mp3
#         2/13 Living On Video
#         Status code: 200 and took 0:00:00.43357
#         http://tut-audio.su/download-music/9179077/dj-mango-man-living-on-video.mp3
#         3/13 Diamond Girl
#         Status code: 200 and took 0:00:00.44941
#         http://tut-audio.su/download-music/9179078/dj-mango-man-diamond-girl.mp3
#         4/13 Funky Town
#         Status code: 200 and took 0:00:00.36211
#         http://tut-audio.su/download-music/9179079/dj-mango-man-funky-town.mp3
#         5/13 All Night
#         Status code: 200 and took 0:00:00.33824
#         http://tut-audio.su/download-music/9179080/dj-mango-man-all-night.mp3
#         6/13 Sweet Dreams
#         Status code: 200 and took 0:00:00.45601
#         http://tut-audio.su/download-music/9179081/dj-mango-man-sweet-dreams.mp3
#         7/13 Dreaming
#         Status code: 200 and took 0:00:00.51633
#         http://tut-audio.su/download-music/9179082/dj-mango-man-dreaming.mp3
#         8/13 La Chica Especial
#         Status code: 200 and took 0:00:00.44576
#         http://tut-audio.su/download-music/9179084/dj-mango-man-la-chica-especial.mp3
#         9/13 Chica Diamante
#         Status code: 200 and took 0:00:00.37103
#         http://tut-audio.su/download-music/9179085/dj-mango-man-chica-diamante.mp3
#         10/13 When I Hear Music
#         Status code: 200 and took 0:00:00.45632
#         http://tut-audio.su/download-music/9179086/dj-mango-man-when-i-hear-music.mp3
#         11/13 Spring Love
#         Status code: 200 and took 0:00:00.39527
#         http://tut-audio.su/download-music/9179087/dj-mango-man-spring-love.mp3
#         12/13 Show Me
#         Status code: 200 and took 0:00:00.46934
#         http://tut-audio.su/download-music/9179088/dj-mango-man-show-me.mp3
#         13/13 Dreaming of Love
#         Status code: 200 and took 0:00:01.43871
#         http://tut-audio.su/download-music/9179089/dj-mango-man-dreaming-of-love.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 13, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-007-james-bond-themes-download-5855600.html (3)
#    New Artist Highlight Orchestra and Singers added to data base!
#    This album has been added to the data base:
#      Artist: Highlight Orchestra and Singers
#      Album name: 007 James Bond Themes
#      Year: 2013
#      Cover: http://tut-audio.su/alb-mus/5855600-460x460/007-james-bond-themes.jpg
#         1/19 Casino Royale
#         Status code: 200 and took 0:00:01.01472
#         http://tut-audio.su/download-music/14474034/highlight-orchestra-and-singers-casino-royale.mp3
#         2/19 Diamonds Are Forever
#         Status code: 200 and took 0:00:00.43831
#         http://tut-audio.su/download-music/14474035/highlight-orchestra-and-singers-diamonds-are-forever.mp3
#         3/19 Goldeneye
#         Status code: 200 and took 0:00:00.46783
#         http://tut-audio.su/download-music/14474036/highlight-orchestra-and-singers-goldeneye.mp3
#         4/19 The Living Daylights
#         Status code: 200 and took 0:00:00.45432
#         http://tut-audio.su/download-music/14474037/highlight-orchestra-and-singers-the-living-daylights.mp3
#         5/19 Moonraker
#         Status code: 200 and took 0:00:00.43330
#         http://tut-audio.su/download-music/14474038/highlight-orchestra-and-singers-moonraker.mp3
#         6/19 The Man With the Golden Gun
#         Status code: 200 and took 0:00:00.40729
#         http://tut-audio.su/download-music/14474039/highlight-orchestra-and-singers-the-man-with-the-golden-gun.mp3
#         7/19 All Time High
#         Status code: 200 and took 0:00:00.39277
#         http://tut-audio.su/download-music/14474040/highlight-orchestra-and-singers-all-time-high.mp3
#         8/19 Goldfinger
#         Status code: 200 and took 0:00:00.59842
#         http://tut-audio.su/download-music/14474041/highlight-orchestra-and-singers-goldfinger.mp3
#         9/19 Mr. Kiss Kss Bang Bang
#         Status code: 200 and took 0:00:05.25101
#         http://tut-audio.su/download-music/14474042/highlight-orchestra-and-singers-mr-kiss-kss-bang-bang.mp3
#         10/19 Thunderball
#         Status code: 200 and took 0:00:00.78067
#         http://tut-audio.su/download-music/14474043/highlight-orchestra-and-singers-thunderball.mp3
#         11/19 For Your Eyes Only
#         Status code: 200 and took 0:00:00.61266
#         http://tut-audio.su/download-music/14474044/highlight-orchestra-and-singers-for-your-eyes-only.mp3
#         12/19 You Only Live Twice
#         Status code: 200 and took 0:00:00.69368
#         http://tut-audio.su/download-music/14474045/highlight-orchestra-and-singers-you-only-live-twice.mp3
#         13/19 From Russia With Love
#         Status code: 200 and took 0:00:00.93495
#         http://tut-audio.su/download-music/14474046/highlight-orchestra-and-singers-from-russia-with-love.mp3
#         14/19 Live and Let Die
#         Status code: 200 and took 0:00:00.42462
#         http://tut-audio.su/download-music/14474047/highlight-orchestra-and-singers-live-and-let-die.mp3
#         15/19 Nobody Does It Better
#         Status code: 200 and took 0:00:00.46272
#         http://tut-audio.su/download-music/14474048/highlight-orchestra-and-singers-nobody-does-it-better.mp3
#         16/19 Never Say Never Again
#         Status code: 200 and took 0:00:00.63093
#         http://tut-audio.su/download-music/14474049/highlight-orchestra-and-singers-never-say-never-again.mp3
#         17/19 James Bond Theme
#         Status code: 200 and took 0:00:00.49248
#         http://tut-audio.su/download-music/14474050/highlight-orchestra-and-singers-james-bond-theme.mp3
#         18/19 Licence to Kill
#         Status code: 200 and took 0:00:00.40233
#         http://tut-audio.su/download-music/14474051/highlight-orchestra-and-singers-licence-to-kill.mp3
#         19/19 A View to a Kill
#         Status code: 200 and took 0:00:00.44688
#         http://tut-audio.su/download-music/14474052/highlight-orchestra-and-singers-a-view-to-a-kill.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 19, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-jackito-007-one-mic-one-man-download-6690986.html (4)
#    New Artist Jackito added to data base!
#    This album has been added to the data base:
#      Artist: Jackito
#      Album name: Jackito 007 (One mic, one man)
#      Year: 2014
#      Cover: http://tut-audio.su/alb-mus/6690986-460x460/jackito-007-one-mic-one-man.jpg
#         1/7 Pesevere
#         Status code: 200 and took 0:00:00.45165
#         http://tut-audio.su/download-music/21779842/jackito-pesevere.mp3
#         2/7 Mission accomplie
#         Status code: 200 and took 0:00:00.47410
#         http://tut-audio.su/download-music/21779843/jackito-mission-accomplie.mp3
#         3/7 Lanmou doudou
#         Status code: 200 and took 0:00:00.63192
#         http://tut-audio.su/download-music/21779844/jackito-lanmou-doudou.mp3
#         4/7 K rément
#         Status code: 200 and took 0:00:00.50192
#         http://tut-audio.su/download-music/21779845/jackito-k-rement.mp3
#         5/7 Biznis pam
#         Status code: 200 and took 0:00:00.46880
#         http://tut-audio.su/download-music/21779846/jackito-biznis-pam.mp3
#         6/7 5 sens + 1
#         Status code: 200 and took 0:00:00.45873
#         http://tut-audio.su/download-music/21779847/jackito-5-sens-1.mp3
#         7/7 Myan myan
#         Status code: 200 and took 0:00:00.56524
#         http://tut-audio.su/download-music/21779848/jackito-myan-myan.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 7, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-a-man-and-his-music-the-essential-ray-barretto-download-4961368.html (5)
#    New Artist Ray Barretto added to data base!
#    This album has been added to the data base:
#      Artist: Ray Barretto
#      Album name: A Man And His Music: The Essential Ray Barretto
#      Year: 2010
#      Cover: http://tut-audio.su/alb-mus/4961368-460x460/a-man-and-his-music-the-essential-ray-barretto.jpg
#         1/18 Soul Drummers
#         Status code: 200 and took 0:00:00.37640
#         http://tut-audio.su/download-music/6008754/ray-barretto-soul-drummers.mp3
#         2/18 Ya Vez
#         Status code: 200 and took 0:00:00.38075
#         http://tut-audio.su/download-music/6012103/ray-barretto-ya-vez.mp3
#         3/18 La Pelota
#         Status code: 200 and took 0:00:00.84229
#         http://tut-audio.su/download-music/6019817/ray-barretto-la-pelota.mp3
#         4/18 Vale Mas Un Guaguanco
#         Status code: 200 and took 0:00:00.76161
#         http://tut-audio.su/download-music/6028307/ray-barretto-vale-mas-un-guaguanco.mp3
#         5/18 Right On
#         Status code: 200 and took 0:00:00.43318
#         http://tut-audio.su/download-music/6043758/ray-barretto-right-on.mp3
#         6/18 Senor 007
#         Status code: 200 and took 0:00:00.43224
#         http://tut-audio.su/download-music/6043759/ray-barretto-senor-007.mp3
#         7/18 Do You Dig It
#         Status code: 200 and took 0:00:01.35029
#         http://tut-audio.su/download-music/6043765/ray-barretto-do-you-dig-it.mp3
#         8/18 El Bantú
#         Status code: 200 and took 0:00:00.43917
#         http://tut-audio.su/download-music/6043767/ray-barretto-el-bantu.mp3
#         9/18 Que Viva La Musica
#         Status code: 200 and took 0:00:00.36969
#         http://tut-audio.su/download-music/6052629/ray-barretto-que-viva-la-musica.mp3
#         10/18 Arrepiéntete
#         Status code: 200 and took 0:00:00.47163
#         http://tut-audio.su/download-music/6052632/ray-barretto-arrepientete.mp3
#         11/18 Tu Propio Dolor
#         Status code: 200 and took 0:00:00.45787
#         http://tut-audio.su/download-music/6053728/ray-barretto-tu-propio-dolor.mp3
#         12/18 Manos Duras
#         Status code: 200 and took 0:00:01.18646
#         http://tut-audio.su/download-music/6057094/ray-barretto-manos-duras.mp3
#         13/18 The Other Road
#         Status code: 200 and took 0:00:00.50555
#         http://tut-audio.su/download-music/6057096/ray-barretto-the-other-road.mp3
#         14/18 Fuerza Gigante (Giant Force)
#         Status code: 200 and took 0:00:00.42188
#         http://tut-audio.su/download-music/6057097/ray-barretto-fuerza-gigante-giant-force.mp3
#         15/18 Aguadilla
#         Status code: 200 and took 0:00:00.43273
#         http://tut-audio.su/download-music/6057098/ray-barretto-aguadilla.mp3
#         16/18 Rhythm Of Life
#         Status code: 200 and took 0:00:01.00705
#         http://tut-audio.su/download-music/6057099/ray-barretto-rhythm-of-life.mp3
#         17/18 Lucretia The Cat
#         Status code: 200 and took 0:00:00.52913
#         http://tut-audio.su/download-music/6057100/ray-barretto-lucretia-the-cat.mp3
#         18/18 Cocinando
#         Status code: 200 and took 0:00:00.63001
#         http://tut-audio.su/download-music/6057101/ray-barretto-cocinando.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 18, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-c-i-discoteque-vol-1-download-5138130.html (6)
#    New Artist Gilbert added to data base!
#    This album has been added to the data base:
#      Artist: Gilbert
#      Album name: C.I.Discoteque Vol 1
#      Year:
#      Cover: http://tut-audio.su/alb-mus/5138130-460x460/c-i-discoteque-vol-1.jpg
#         1/10 Mani In Alto
#         Status code: 200 and took 0:00:00.67476
#         http://tut-audio.su/download-music/7698546/gilbert-mani-in-alto.mp3
#         2/10 Revolution
#         Status code: 200 and took 0:00:00.44833
#         http://tut-audio.su/download-music/7698547/007-man-revolution.mp3
#         3/10 Start
#         Status code: 200 and took 0:00:00.41923
#         http://tut-audio.su/download-music/7698548/fabio-santi-start.mp3
#         4/10 Tecnomagro
#         Status code: 200 and took 0:00:00.35827
#         http://tut-audio.su/download-music/7698549/leo-magro-tecnomagro.mp3
#         5/10 Smoke
#         Status code: 200 and took 0:00:00.35915
#         http://tut-audio.su/download-music/7698550/luca-guerrieri-smoke.mp3
#         6/10 Dederica Ale
#         Status code: 200 and took 0:00:00.58241
#         http://tut-audio.su/download-music/7698551/ale-dederica-ale.mp3
#         7/10 Tribantella
#         Status code: 200 and took 0:00:00.41334
#         http://tut-audio.su/download-music/7698552/alessio-giannelli-tribantella.mp3
#         8/10 Sofia
#         Status code: 200 and took 0:00:00.49842
#         http://tut-audio.su/download-music/7698553/cicco-d-j-sofia.mp3
#         9/10 Black Out
#         Status code: 200 and took 0:00:00.66873
#         http://tut-audio.su/download-music/7698554/riccardino-black-out.mp3
#         10/10 Latin Day
#         Status code: 200 and took 0:00:00.55970
#         http://tut-audio.su/download-music/7698555/lorenzo-c-latin-day.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 10, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-007-the-music-of-james-bond-download-5184697.html (7)
#    New Artist The Original Movies Orchestra added to data base!
#    This album has been added to the data base:
#      Artist: The Original Movies Orchestra
#      Album name: 007 The Music Of James Bond
#      Year: 2007
#      Cover: http://tut-audio.su/alb-mus/5184697-460x460/007-the-music-of-james-bond.jpg
#         1/9 The Man With The Golden Gun Main Title (Tha Man With Golden Gun 1974)
#         Status code: 200 and took 0:00:00.36636
#         http://tut-audio.su/download-music/7769249/the-original-movies-orchestra-the-man-with-the-golden-gun-main-title-tha-man-with-golden-gun-1974.mp3
#         2/9 A View To A Kill Main Title (A View To A Kill 1985)
#         Status code: 200 and took 0:00:00.46742
#         http://tut-audio.su/download-music/7769254/the-original-movies-orchestra-a-view-to-a-kill-main-title-a-view-to-a-kill-1985.mp3
#         3/9 Thunderball Main Title (Thunderball 1965)
#         Status code: 200 and took 0:00:01.01863
#         http://tut-audio.su/download-music/7769255/the-original-movies-orchestra-thunderball-main-title-thunderball-1965.mp3
#         4/9 Diamonds Are Forever Main Title (Diamonds Are Forever 1971)
#         Status code: 200 and took 0:00:00.40263
#         http://tut-audio.su/download-music/7769260/the-original-movies-orchestra-diamonds-are-forever-main-title-diamonds-are-forever-1971.mp3
#         5/9 Never Say Never Again
#         Status code: 200 and took 0:00:00.88760
#         http://tut-audio.su/download-music/8206459/the-original-movies-orchestra-never-say-never-again.mp3
#         6/9 Goldeneye
#         Status code: 200 and took 0:00:00.89263
#         http://tut-audio.su/download-music/8206461/the-original-movies-orchestra-goldeneye.mp3
#         7/9 Dr. No
#         Status code: 200 and took 0:00:00.44425
#         http://tut-audio.su/download-music/8206464/the-original-movies-orchestra-dr-no.mp3
#         8/9 Licence To Kill
#         Status code: 200 and took 0:00:00.42878
#         http://tut-audio.su/download-music/8206466/the-original-movies-orchestra-licence-to-kill.mp3
#         9/9 Nobody Does It Better
#         Status code: 200 and took 0:00:00.41193
#         http://tut-audio.su/download-music/8206467/the-original-movies-orchestra-nobody-does-it-better.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 9, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-007-james-bond-classics-skyfall-50-years-edition-download-5451728.html (8)
#    New Artist 007 Collective added to data base!
#    This album has been added to the data base:
#      Artist: 007 Collective
#      Album name: 007 - James Bond Classics - Skyfall ' 50 years Edition '
#      Year: 2012
#      Cover: http://tut-audio.su/alb-mus/5451728-460x460/007-james-bond-classics-skyfall-50-years-edition.jpg
#         1/25 The Living Daylights ( From 'The Living Daylights' )
#         Status code: 200 and took 0:00:00.49945
#         http://tut-audio.su/download-music/10498879/007-collective-the-living-daylights-from-the-living-daylights.mp3
#         2/25 Diamonds Are Forever ( From 'Diamonds Are Forever' )
#         Status code: 200 and took 0:00:00.72463
#         http://tut-audio.su/download-music/10498880/007-collective-diamonds-are-forever-from-diamonds-are-forever.mp3
#         3/25 A View To A Kill ( From 'A View To A Kill' )
#         Track is missing!
#         Status code: 404 and took 0:00:00.32792
#         http://tut-audio.su/download-music/10498881/007-collective-a-view-to-a-kill-from-a-view-to-a-kill.mp3
#         4/25 The World Is Not Enough ( From 'The World Is Not Enough' )
#         Status code: 200 and took 0:00:00.37827
#         http://tut-audio.su/download-music/10498882/007-collective-the-world-is-not-enough-from-the-world-is-not-enough.mp3
#         5/25 Never Say Never Again ( From 'Never Say Never Again' )
#         Status code: 200 and took 0:00:00.39323
#         http://tut-audio.su/download-music/10498883/007-collective-never-say-never-again-from-never-say-never-again.mp3
#         6/25 Goldfinger ( From 'Goldfinger' )
#         Status code: 200 and took 0:00:00.39541
#         http://tut-audio.su/download-music/10498884/007-collective-goldfinger-from-goldfinger.mp3
#         7/25 You Only Live Twice
#         Status code: 200 and took 0:00:00.34207
#         http://tut-audio.su/download-music/10498885/007-collective-you-only-live-twice.mp3
#         8/25 The Man With The Golden Gun ( From 'The Man With The Golden Gun' )
#         Status code: 200 and took 0:00:00.40442
#         http://tut-audio.su/download-music/10498886/007-collective-the-man-with-the-golden-gun-from-the-man-with-the-golden-gun.mp3
#         9/25 On Her Majestys Secret Service ( From 'On Her Majestys Secret Service' )
#         Status code: 200 and took 0:00:00.52174
#         http://tut-audio.su/download-music/10498887/007-collective-on-her-majestys-secret-service-from-on-her-majestys-secret-service.mp3
#         10/25 Another Way To Die ( From 'Quantum of Solace' )
#         Status code: 200 and took 0:00:00.63839
#         http://tut-audio.su/download-music/10498888/007-collective-another-way-to-die-from-quantum-of-solace.mp3
#         11/25 Skyfall ( From 'Skyfall' )
#         Status code: 200 and took 0:00:00.48010
#         http://tut-audio.su/download-music/10498889/007-collective-skyfall-from-skyfall.mp3
#         12/25 All Time High ( From 'Octopussy' )
#         Status code: 200 and took 0:00:00.42734
#         http://tut-audio.su/download-music/10498890/007-collective-all-time-high-from-octopussy.mp3
#         13/25 Tomorrow Never Dies ( From 'Tomorrow Never Dies' )
#         Status code: 200 and took 0:00:00.53634
#         http://tut-audio.su/download-music/10498891/007-collective-tomorrow-never-dies-from-tomorrow-never-dies.mp3
#         14/25 Die Another Day ( From 'Die Another Day' )
#         Status code: 200 and took 0:00:00.35657
#         http://tut-audio.su/download-music/10498892/007-collective-die-another-day-from-die-another-day.mp3
#         15/25 From Russia With Love ( From 'Russia With Love' )
#         Status code: 200 and took 0:00:01.26721
#         http://tut-audio.su/download-music/10498893/007-collective-from-russia-with-love-from-russia-with-love.mp3
#         16/25 For Your Eyes Only ( From 'For Your Eyes Only' )
#         Status code: 200 and took 0:00:00.42562
#         http://tut-audio.su/download-music/10498894/007-collective-for-your-eyes-only-from-for-your-eyes-only.mp3
#         17/25 Licence To Kill ( From 'Licence To Kill' )
#         Status code: 200 and took 0:00:00.65358
#         http://tut-audio.su/download-music/10498895/007-collective-licence-to-kill-from-licence-to-kill.mp3
#         18/25 Moonraker ( From 'Moonraker' )
#         Status code: 200 and took 0:00:00.62150
#         http://tut-audio.su/download-music/10498896/007-collective-moonraker-from-moonraker.mp3
#         19/25 Casino Royale ( From 'Casino Royale' )
#         Status code: 200 and took 0:00:00.32595
#         http://tut-audio.su/download-music/10498897/007-collective-casino-royale-from-casino-royale.mp3
#         20/25 Nobody Does It Better ( From 'Spy Who Loved Me' )
#         Status code: 200 and took 0:00:00.41218
#         http://tut-audio.su/download-music/10498898/007-collective-nobody-does-it-better-from-spy-who-loved-me.mp3
#         21/25 Doctor No ( From 'Doctor No' )
#         Status code: 200 and took 0:00:00.41258
#         http://tut-audio.su/download-music/10498899/007-collective-doctor-no-from-doctor-no.mp3
#         22/25 Live And Let Die
#         Status code: 200 and took 0:00:00.39160
#         http://tut-audio.su/download-music/10498900/007-collective-live-and-let-die.mp3
#         23/25 You Know My Name ( From 'Casino Royale' )
#         Status code: 200 and took 0:00:00.43679
#         http://tut-audio.su/download-music/10498901/007-collective-you-know-my-name-from-casino-royale.mp3
#         24/25 Thunderball ( From 'Thunderball' )
#         Status code: 200 and took 0:00:00.38723
#         http://tut-audio.su/download-music/10498902/007-collective-thunderball-from-thunderball.mp3
#         25/25 Goldeneye ( From 'Goldeneye' )
#         Status code: 200 and took 0:00:00.59064
#         http://tut-audio.su/download-music/10498903/007-collective-goldeneye-from-goldeneye.mp3
# -------------------------------------------------------------------------------------------
# Missing: 1, Live: 24, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-cinemagic-27-download-5868980.html (9)
#    New Artist Marc Reift added to data base!
#    This album has been added to the data base:
#      Artist: Marc Reift
#      Album name: Cinemagic 27
#      Year: 2013
#      Cover: http://tut-audio.su/alb-mus/5868980-460x460/cinemagic-27.jpg
#         1/9 Moulin Rouge (From "Moulin Rougue")
#         Status code: 200 and took 0:00:48.68246
#         http://tut-audio.su/download-music/14590149/marc-reift-moulin-rouge-from-moulin-rougue.mp3
#         2/9 MacGyver Theme
#         Status code: 200 and took 0:00:00.31848
#         http://tut-audio.su/download-music/14590152/marc-reift-macgyver-theme.mp3
#         3/9 Le Casse: The Burglars / Der Coup (From "The Burglars / De Coup)
#         Status code: 200 and took 0:00:00.36097
#         http://tut-audio.su/download-music/14590154/marc-reift-le-casse-the-burglars-der-coup-from-the-burglars-de-coup.mp3
#         4/9 Edelweiss (From "The Sound of Music")
#         Status code: 200 and took 0:00:00.43141
#         http://tut-audio.su/download-music/14590155/marc-reift-edelweiss-from-the-sound-of-music.mp3
#         5/9 Moonraker (From "James Bond 007: Moonraker")
#         Status code: 200 and took 0:00:00.46725
#         http://tut-audio.su/download-music/14590157/marc-reift-moonraker-from-james-bond-007-moonraker.mp3
#         6/9 Murder in the First (From "Meurtre à Alcatraz)
#         Status code: 200 and took 0:00:00.49728
#         http://tut-audio.su/download-music/14590159/marc-reift-murder-in-the-first-from-meurtre-a-alcatraz.mp3
#         7/9 The Man With the Golden Gun (From "James Bond 007: The Man With the Golden Gun")
#         Status code: 200 and took 0:00:00.43372
#         http://tut-audio.su/download-music/14590161/marc-reift-the-man-with-the-golden-gun-from-james-bond-007-the-man-with-the-golden-gun.mp3
#         8/9 Little Tom Thumb (From " Le Petit Poucet")
#         Status code: 200 and took 0:00:00.43475
#         http://tut-audio.su/download-music/14590163/marc-reift-little-tom-thumb-from-le-petit-poucet.mp3
#         9/9 Da Vinci Code (From " The Da Vinci Code")
#         Status code: 200 and took 0:00:00.41763
#         http://tut-audio.su/download-music/14590165/marc-reift-da-vinci-code-from-the-da-vinci-code.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 9, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-007-best-songs-le-piu-belle-colonne-sonore-download-5343963.html (10)
#    New Artist Soundtrack Orchestra added to data base!
#    This album has been added to the data base:
#      Artist: Soundtrack Orchestra
#      Album name: 007 Best Songs : Le più belle colonne sonore
#      Year: 2011
#      Cover: http://tut-audio.su/alb-mus/5343963-460x460/007-best-songs-le-piu-belle-colonne-sonore.jpg
#         1/16 Goldfinger
#         Status code: 200 and took 0:00:00.66726
#         http://tut-audio.su/download-music/9400001/soundtrack-orchestra-goldfinger.mp3
#         2/16 Nobody Does It Better
#         Status code: 200 and took 0:00:00.40353
#         http://tut-audio.su/download-music/9400002/soundtrack-orchestra-nobody-does-it-better.mp3
#         3/16 The Man With the Golden Gun
#         Status code: 200 and took 0:00:00.44443
#         http://tut-audio.su/download-music/9400003/soundtrack-orchestra-the-man-with-the-golden-gun.mp3
#         4/16 Thunderball
#         Status code: 200 and took 0:00:00.41402
#         http://tut-audio.su/download-music/9400004/soundtrack-orchestra-thunderball.mp3
#         5/16 Tomorrow Never Dies
#         Status code: 200 and took 0:00:00.65406
#         http://tut-audio.su/download-music/9400005/soundtrack-orchestra-tomorrow-never-dies.mp3
#         6/16 Casinò Royale
#         Status code: 200 and took 0:00:00.46917
#         http://tut-audio.su/download-music/9400006/soundtrack-orchestra-casino-royale.mp3
#         7/16 Never Say Never Again
#         Status code: 200 and took 0:00:00.57501
#         http://tut-audio.su/download-music/9400007/soundtrack-orchestra-never-say-never-again.mp3
#         8/16 All Time High
#         Status code: 200 and took 0:00:00.71774
#         http://tut-audio.su/download-music/9400008/soundtrack-orchestra-all-time-high.mp3
#         9/16 Live & Let Die
#         Status code: 200 and took 0:00:00.39227
#         http://tut-audio.su/download-music/9400009/soundtrack-orchestra-live-let-die.mp3
#         10/16 The World Is Not Enough
#         Status code: 200 and took 0:00:00.65917
#         http://tut-audio.su/download-music/9400010/soundtrack-orchestra-the-world-is-not-enough.mp3
#         11/16 A View to a Kill
#         Status code: 200 and took 0:00:00.57815
#         http://tut-audio.su/download-music/9400011/soundtrack-orchestra-a-view-to-a-kill.mp3
#         12/16 Moonraker
#         Status code: 200 and took 0:00:01.04219
#         http://tut-audio.su/download-music/9400012/soundtrack-orchestra-moonraker.mp3
#         13/16 From Russia With Love
#         Status code: 200 and took 0:00:00.39901
#         http://tut-audio.su/download-music/9400013/soundtrack-orchestra-from-russia-with-love.mp3
#         14/16 Goldeneye
#         Status code: 200 and took 0:00:00.41363
#         http://tut-audio.su/download-music/9400014/soundtrack-orchestra-goldeneye.mp3
#         15/16 Licence to Kill
#         Status code: 200 and took 0:00:00.68243
#         http://tut-audio.su/download-music/9400015/soundtrack-orchestra-licence-to-kill.mp3
#         16/16 For Your Eyes Only
#         Status code: 200 and took 0:00:00.39841
#         http://tut-audio.su/download-music/9400016/soundtrack-orchestra-for-your-eyes-only.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 16, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-blockbuster-music-download-5935517.html (11)
#    New Artist The Magic Movie Orchestra added to data base!
#    This album has been added to the data base:
#      Artist: The Magic Movie Orchestra
#      Album name: Blockbuster Music
#      Year:
#      Cover: http://tut-audio.su/alb-mus/5935517-460x460/blockbuster-music.jpg
#         1/19 Main Title from James Bond: You Only Live Twice
#         Status code: 200 and took 0:00:00.52890
#         http://tut-audio.su/download-music/10738607/the-magic-movie-orchestra-main-title-from-james-bond-you-only-live-twice.mp3
#         2/19 No Matter What Happens (From "Yentl")
#         Status code: 200 and took 0:00:00.59836
#         http://tut-audio.su/download-music/15063726/movie-sounds-unlimited-no-matter-what-happens-from-yentl.mp3
#         3/19 Black Rain Suite (From "Black Rain")
#         Status code: 200 and took 0:00:00.42285
#         http://tut-audio.su/download-music/15063727/movie-sounds-unlimited-black-rain-suite-from-black-rain.mp3
#         4/19 Star Trek - (Music Inspired By the TV-Series)
#         Status code: 200 and took 0:00:00.46775
#         http://tut-audio.su/download-music/15063729/movie-sounds-unlimited-star-trek-music-inspired-by-the-tv-series.mp3
#         5/19 Sledge Hammer (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.36542
#         http://tut-audio.su/download-music/15063730/movie-sounds-unlimited-sledge-hammer-music-inspired-by-the-film.mp3
#         6/19 Across the Stars (Love Theme from "Star Wars Episode II: Attack of the Clones")
#         Status code: 200 and took 0:00:00.39907
#         http://tut-audio.su/download-music/15063731/movie-sounds-unlimited-across-the-stars-love-theme-from-star-wars-episode-ii-attack-of-the-clones.mp3
#         7/19 Wives and Lovers (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.36695
#         http://tut-audio.su/download-music/15063732/movie-sounds-unlimited-wives-and-lovers-music-inspired-by-the-film.mp3
#         8/19 Papa Can You Hear Me (From "Yentl")
#         Status code: 200 and took 0:00:00.35207
#         http://tut-audio.su/download-music/15063733/movie-sounds-unlimited-papa-can-you-hear-me-from-yentl.mp3
#         9/19 The Black Hole (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.28979
#         http://tut-audio.su/download-music/15063734/movie-sounds-unlimited-the-black-hole-music-inspired-by-the-film.mp3
#         10/19 Persuaders Theme (From "the Persuaders")
#         Status code: 200 and took 0:00:00.30341
#         http://tut-audio.su/download-music/15063735/movie-sounds-unlimited-persuaders-theme-from-the-persuaders.mp3
#         11/19 Baby Elephant Walk (From "Hatari")
#         Status code: 200 and took 0:00:00.41294
#         http://tut-audio.su/download-music/15063736/movie-sounds-unlimited-baby-elephant-walk-from-hatari.mp3
#         12/19 The Man With the Golden Gun (From "James Bond 007 - Der Mann Mit Dem Goldenen Colt")
#         Status code: 200 and took 0:00:00.46748
#         http://tut-audio.su/download-music/15063737/movie-sounds-unlimited-the-man-with-the-golden-gun-from-james-bond-007-der-mann-mit-dem-goldenen-colt.mp3
#         13/19 Remington Steel (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.35794
#         http://tut-audio.su/download-music/15063738/movie-sounds-unlimited-remington-steel-music-inspired-by-the-film.mp3
#         14/19 Hotel (Music Inspired By the Film)
#         Status code: 200 and took 0:00:01.17914
#         http://tut-audio.su/download-music/15063739/movie-sounds-unlimited-hotel-music-inspired-by-the-film.mp3
#         15/19 Love Theme (From "Ben Hur")
#         Status code: 200 and took 0:00:00.50065
#         http://tut-audio.su/download-music/15063740/movie-sounds-unlimited-love-theme-from-ben-hur.mp3
#         16/19 La Dolce Vita (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.60107
#         http://tut-audio.su/download-music/15063741/movie-sounds-unlimited-la-dolce-vita-music-inspired-by-the-film.mp3
#         17/19 Moon River (From "Breakfast At Tiffany's")
#         Status code: 200 and took 0:00:00.45838
#         http://tut-audio.su/download-music/15063742/movie-sounds-unlimited-moon-river-from-breakfast-at-tiffany-s.mp3
#         18/19 What's New Pussycat? (Music Inspired By the Film)
#         Status code: 200 and took 0:00:00.48842
#         http://tut-audio.su/download-music/15063743/movie-sounds-unlimited-what-s-new-pussycat-music-inspired-by-the-film.mp3
#         19/19 From Russia With Love (From "Liebesgrüße Aus Moskau")
#         Status code: 200 and took 0:00:00.68954
#         http://tut-audio.su/download-music/15063744/movie-sounds-unlimited-from-russia-with-love-from-liebesgrusse-aus-moskau.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 19, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-bond-007-tribute-ringtones-download-6263755.html (12)
#    New Artist DJ MixMasters added to data base!
#    This album has been added to the data base:
#      Artist: DJ MixMasters
#      Album name: Bond 007 Tribute Ringtones
#      Year: 2013
#      Cover: http://tut-audio.su/alb-mus/6263755-460x460/bond-007-tribute-ringtones.jpg
#         1/22 Thunderball (Tribute in the Style of Tom Jones)
#         Status code: 200 and took 0:00:01.13221
#         http://tut-audio.su/download-music/18020706/dj-mixmasters-thunderball-tribute-in-the-style-of-tom-jones.mp3
#         2/22 Skyfall (Tribute in the Style of Adele)
#         Track is missing!
#         Status code: 404 and took 0:00:00.30386
#         http://tut-audio.su/download-music/18020707/dj-mixmasters-skyfall-tribute-in-the-style-of-adele.mp3
#         3/22 We Have All the Time in the World (Tribute in the Style of Louis Armstrong)
#         Status code: 200 and took 0:00:00.45460
#         http://tut-audio.su/download-music/18020708/dj-mixmasters-we-have-all-the-time-in-the-world-tribute-in-the-style-of-louis-armstrong.mp3
#         4/22 Nobody Does It Better (Tribute in the Style of Carly Simon)
#         Status code: 200 and took 0:00:00.89559
#         http://tut-audio.su/download-music/18020709/dj-mixmasters-nobody-does-it-better-tribute-in-the-style-of-carly-simon.mp3
#         5/22 You Only Live Twice (Tribute in the Style of Nancy Sinatra)
#         Status code: 200 and took 0:00:00.38755
#         http://tut-audio.su/download-music/18020710/dj-mixmasters-you-only-live-twice-tribute-in-the-style-of-nancy-sinatra.mp3
#         6/22 Die Another Day (Tribute in the Style of Madonna)
#         Track is missing!
#         Status code: 404 and took 0:00:00.29825
#         http://tut-audio.su/download-music/18020711/dj-mixmasters-die-another-day-tribute-in-the-style-of-madonna.mp3
#         7/22 The Living Daylights (Tribute in the Style of a-Ha)
#         Track is missing!
#         Status code: 404 and took 0:00:00.29306
#         http://tut-audio.su/download-music/18020712/dj-mixmasters-the-living-daylights-tribute-in-the-style-of-a-ha.mp3
#         8/22 From Russia With Love (Tribute in the Style of Matt Monro)
#         Status code: 200 and took 0:00:00.30484
#         http://tut-audio.su/download-music/18020713/dj-mixmasters-from-russia-with-love-tribute-in-the-style-of-matt-monro.mp3
#         9/22 You Know My Name (Tribute in the Style of Chris Cornell)
#         Status code: 200 and took 0:00:00.33855
#         http://tut-audio.su/download-music/18020714/dj-mixmasters-you-know-my-name-tribute-in-the-style-of-chris-cornell.mp3
#         10/22 For Your Eyes Only (Tribute in the Style of Sheena Easton)
#         Status code: 200 and took 0:00:00.40925
#         http://tut-audio.su/download-music/18020715/dj-mixmasters-for-your-eyes-only-tribute-in-the-style-of-sheena-easton.mp3
#         11/22 All Time High (Tribute in the Style of Rita Coolidge)
#         Status code: 200 and took 0:00:00.34850
#         http://tut-audio.su/download-music/18020716/dj-mixmasters-all-time-high-tribute-in-the-style-of-rita-coolidge.mp3
#         12/22 The World Is Not Enough (Tribute in the Style of Garbage)
#         Status code: 200 and took 0:00:00.57757
#         http://tut-audio.su/download-music/18020717/dj-mixmasters-the-world-is-not-enough-tribute-in-the-style-of-garbage.mp3
#         13/22 Tomorrow Never Dies (Tribute in the Style of Sheryl Crow)
#         Status code: 200 and took 0:00:00.35643
#         http://tut-audio.su/download-music/18020718/dj-mixmasters-tomorrow-never-dies-tribute-in-the-style-of-sheryl-crow.mp3
#         14/22 Moonraker (Tribute in the Style of Shirley Bassey)
#         Status code: 200 and took 0:00:00.78314
#         http://tut-audio.su/download-music/18020719/dj-mixmasters-moonraker-tribute-in-the-style-of-shirley-bassey.mp3
#         15/22 Diamonds Are Forever (Tribute in the Style of Shirley Bassey)
#         Status code: 200 and took 0:00:00.35467
#         http://tut-audio.su/download-music/18020720/dj-mixmasters-diamonds-are-forever-tribute-in-the-style-of-shirley-bassey.mp3
#         16/22 The Man With the Golden Gun (Tribute in the Style of Lulu)
#         Status code: 200 and took 0:00:00.47082
#         http://tut-audio.su/download-music/18020721/dj-mixmasters-the-man-with-the-golden-gun-tribute-in-the-style-of-lulu.mp3
#         17/22 A View to Kill (Tribute in the Style of Duran Duran)
#         Track is missing!
#         Status code: 404 and took 0:00:00.29842
#         http://tut-audio.su/download-music/18020722/dj-mixmasters-a-view-to-kill-tribute-in-the-style-of-duran-duran.mp3
#         18/22 Goldfinger (Tribute in the Style of Shirley Bassey)
#         Status code: 200 and took 0:00:00.31322
#         http://tut-audio.su/download-music/18020723/dj-mixmasters-goldfinger-tribute-in-the-style-of-shirley-bassey.mp3
#         19/22 Live and Let Die (Tribute in the Style of Paul McCartney)
#         Status code: 200 and took 0:00:00.39637
#         http://tut-audio.su/download-music/18020724/dj-mixmasters-live-and-let-die-tribute-in-the-style-of-paul-mccartney.mp3
#         20/22 Goldeneye (Tribute in the Style of Tina Turner)
#         Status code: 200 and took 0:00:00.32038
#         http://tut-audio.su/download-music/18020725/dj-mixmasters-goldeneye-tribute-in-the-style-of-tina-turner.mp3
#         21/22 Licence to Kill (Tribute in the Style of Gladys Knight)
#         Track is missing!
#         Status code: 404 and took 0:00:00.29532
#         http://tut-audio.su/download-music/18020726/dj-mixmasters-licence-to-kill-tribute-in-the-style-of-gladys-knight.mp3
#         22/22 Another Way to Die (Tribute in the Style of Jack White & Alicia Keys)
#         Status code: 200 and took 0:00:00.38405
#         http://tut-audio.su/download-music/18020727/dj-mixmasters-another-way-to-die-tribute-in-the-style-of-jack-white-alicia-keys.mp3
# -------------------------------------------------------------------------------------------
# Missing: 5, Live: 17, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-tribute-to-the-greatest-theme-songs-of-james-bond-007-download-5451524.html (13)
#    New Artist The Hollywood Symphony Orchestra & Guests added to data base!
#    This album has been added to the data base:
#      Artist: The Hollywood Symphony Orchestra & Guests
#      Album name: Tribute to the Greatest Theme Songs of JAMES BOND 007......
#      Year: 2012
#      Cover: http://tut-audio.su/alb-mus/5451524-460x460/tribute-to-the-greatest-theme-songs-of-james-bond-007.jpg
#         1/15 All Time High (Octopussy)
#         Status code: 200 and took 0:00:00.46929
#         http://tut-audio.su/download-music/10495775/the-hollywood-symphony-orchestra-guests-all-time-high-octopussy.mp3
#         2/15 Goldeneye
#         Status code: 200 and took 0:00:00.35818
#         http://tut-audio.su/download-music/10495776/the-hollywood-symphony-orchestra-guests-goldeneye.mp3
#         3/15 Live and Let Die
#         Status code: 200 and took 0:00:02.12253
#         http://tut-audio.su/download-music/10495777/the-hollywood-symphony-orchestra-guests-live-and-let-die.mp3
#         4/15 Tomorrow Never Dies
#         Status code: 200 and took 0:00:01.51912
#         http://tut-audio.su/download-music/10495778/the-hollywood-symphony-orchestra-guests-tomorrow-never-dies.mp3
#         5/15 For Your Eyes Only
#         Status code: 200 and took 0:00:00.61887
#         http://tut-audio.su/download-music/10495779/the-hollywood-symphony-orchestra-guests-for-your-eyes-only.mp3
#         6/15 Moonraker
#         Status code: 200 and took 0:00:02.63329
#         http://tut-audio.su/download-music/10495780/the-hollywood-symphony-orchestra-guests-moonraker.mp3
#         7/15 You Only Live Twice
#         Status code: 200 and took 0:00:00.37460
#         http://tut-audio.su/download-music/10495781/the-hollywood-symphony-orchestra-guests-you-only-live-twice.mp3
#         8/15 The Man With The Golden Gun
#         Status code: 200 and took 0:00:00.57342
#         http://tut-audio.su/download-music/10495782/the-hollywood-symphony-orchestra-guests-the-man-with-the-golden-gun.mp3
#         9/15 Nobody Does It Better (The Spy who loved me)
#         Status code: 200 and took 0:00:00.56647
#         http://tut-audio.su/download-music/10495783/the-hollywood-symphony-orchestra-guests-nobody-does-it-better-the-spy-who-loved-me.mp3
#         10/15 The World Is Not Enough
#         Status code: 200 and took 0:00:02.03118
#         http://tut-audio.su/download-music/10495784/the-hollywood-symphony-orchestra-guests-the-world-is-not-enough.mp3
#         11/15 Skyfall
#         Status code: 200 and took 0:00:00.63791
#         http://tut-audio.su/download-music/10495785/katie-berry-skyfall.mp3
#         12/15 Goldfinger
#         Status code: 200 and took 0:00:00.56687
#         http://tut-audio.su/download-music/10495786/the-hollywood-symphony-orchestra-guests-goldfinger.mp3
#         13/15 A View To A Kill
#         Track is missing!
#         Status code: 404 and took 0:00:00.36581
#         http://tut-audio.su/download-music/10495787/the-hollywood-symphony-orchestra-guests-a-view-to-a-kill.mp3
#         14/15 The Living Daylights
#         Status code: 200 and took 0:00:02.82124
#         http://tut-audio.su/download-music/10495788/the-hollywood-symphony-orchestra-guests-the-living-daylights.mp3
#         15/15 Diamonds Are Forever
#         Status code: 200 and took 0:00:00.65133
#         http://tut-audio.su/download-music/10495789/the-hollywood-symphony-orchestra-guests-diamonds-are-forever.mp3
# -------------------------------------------------------------------------------------------
# Missing: 1, Live: 14, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-james-bond-007-ultimate-collection-vol-2-download-5422557.html (14)
#    Artist High School Music Band retrieved from data base!
#    This album has been added to the data base:
#      Artist: High School Music Band
#      Album name: James Bond 007 Ultimate Collection, Vol. 2
#      Year: 2012
#      Cover: http://tut-audio.su/alb-mus/5422557-460x460/james-bond-007-ultimate-collection-vol-2.jpg
#         1/20 Live & Let Die
#         Status code: 200 and took 0:00:00.44156
#         http://tut-audio.su/download-music/10220379/high-school-music-band-live-let-die.mp3
#         2/20 A View to a Kill
#         Status code: 200 and took 0:00:01.06412
#         http://tut-audio.su/download-music/10220380/high-school-music-band-a-view-to-a-kill.mp3
#         3/20 The Man With the Golden Gun
#         Status code: 200 and took 0:00:00.36628
#         http://tut-audio.su/download-music/10220381/high-school-music-band-the-man-with-the-golden-gun.mp3
#         4/20 You Only Live Twice
#         Status code: 200 and took 0:00:00.41653
#         http://tut-audio.su/download-music/10220382/high-school-music-band-you-only-live-twice.mp3
#         5/20 Licence to Kill
#         Status code: 200 and took 0:00:00.47398
#         http://tut-audio.su/download-music/10220383/high-school-music-band-licence-to-kill.mp3
#         6/20 Never Say Never Again
#         Status code: 200 and took 0:00:00.39535
#         http://tut-audio.su/download-music/10220384/high-school-music-band-never-say-never-again.mp3
#         7/20 Casino Royale
#         Status code: 200 and took 0:00:00.38427
#         http://tut-audio.su/download-music/10220385/high-school-music-band-casino-royale.mp3
#         8/20 The Living Daylights
# ...
#         http://tut-audio.su/download-music/8726538/renato-carosone-the-living-daylights.mp3
#         3/10 James Bond Theme
#         Status code: 200 and took 0:00:00.41091
#         http://tut-audio.su/download-music/8726542/peppino-di-capri-james-bond-theme.mp3
#         4/10 License to Kill
#         Status code: 200 and took 0:00:00.38140
#         http://tut-audio.su/download-music/8726543/claudio-villa-license-to-kill.mp3
#         5/10 The Man With the Golden Gun
#         Status code: 200 and took 0:00:00.34150
#         http://tut-audio.su/download-music/8726544/the-007-orchestra-the-man-with-the-golden-gun.mp3
#         6/10 A View to a Kill
#         Status code: 200 and took 0:00:00.36757
#         http://tut-audio.su/download-music/8726546/adriano-celentano-a-view-to-a-kill.mp3
#         7/10 Casino Royale
#         Status code: 200 and took 0:00:00.66889
#         http://tut-audio.su/download-music/8726547/claudio-villa-casino-royale.mp3
#         8/10 For Your Eyes Only
#         Status code: 200 and took 0:00:00.52254
#         http://tut-audio.su/download-music/8726548/renato-carosone-for-your-eyes-only.mp3
#         9/10 Never Say Never Again
#         Status code: 200 and took 0:00:00.38027
#         http://tut-audio.su/download-music/8726549/giorgio-gaber-never-say-never-again.mp3
#         10/10 All Time High
#         Status code: 200 and took 0:00:00.44631
#         http://tut-audio.su/download-music/8726550/milva-all-time-high.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 10, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-riding-a-cannibal-horse-from-here-to-download-5657380.html (19)
#    New Artist The Orange Man Theory added to data base!
#    This album has been added to the data base:
#      Artist: The Orange Man Theory
#      Album name: Riding A Cannibal Horse From Here To...
#      Year: 2005
#      Cover: http://tut-audio.su/alb-mus/5657380-460x460/riding-a-cannibal-horse-from-here-to.jpg
#         1/9 Vortex Of Cows Into The Sweet Tornado
#         Status code: 200 and took 0:00:01.06714
#         http://tut-audio.su/download-music/12747355/the-orange-man-theory-vortex-of-cows-into-the-sweet-tornado.mp3
#         2/9 007 (CE FA NA PIPPA)
#         Status code: 200 and took 0:00:00.38114
#         http://tut-audio.su/download-music/12747356/the-orange-man-theory-007-ce-fa-na-pippa.mp3
#         3/9 Merendina Will Have His Revenge On Capeside
#         Status code: 200 and took 0:00:00.66989
#         http://tut-audio.su/download-music/12747357/the-orange-man-theory-merendina-will-have-his-revenge-on-capeside.mp3
#         4/9 Where We're Going We Don't Need Roads!
#         Status code: 200 and took 0:00:00.39678
#         http://tut-audio.su/download-music/12747358/the-orange-man-theory-where-we-re-going-we-don-t-need-roads.mp3
#         5/9 Biollante's Dawn
#         Status code: 200 and took 0:00:00.41740
#         http://tut-audio.su/download-music/12747359/the-orange-man-theory-biollante-s-dawn.mp3
#         6/9 Riding A Cannibal Horse From Here To Clinton, MA
#         Status code: 200 and took 0:00:00.71236
#         http://tut-audio.su/download-music/12747360/the-orange-man-theory-riding-a-cannibal-horse-from-here-to-clinton-ma.mp3
#         7/9 Introduicing Ourselves To The Masses
#         Status code: 200 and took 0:00:00.37826
#         http://tut-audio.su/download-music/12747361/the-orange-man-theory-introduicing-ourselves-to-the-masses.mp3
#         8/9 Vampires In The Sun (Surfin' Transylvania)
#         Status code: 200 and took 0:00:00.39365
#         http://tut-audio.su/download-music/12747362/the-orange-man-theory-vampires-in-the-sun-surfin-transylvania.mp3
#         9/9 The Way To Rock
#         Status code: 200 and took 0:00:00.46025
#         http://tut-audio.su/download-music/12747363/the-orange-man-theory-the-way-to-rock.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 9, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-landscapes-download-5524387.html (20)
#    New Artist The Scene added to data base!
#    This album has been added to the data base:
#      Artist: The Scene
#      Album name: Landscapes
#      Year:
#      Cover: http://tut-audio.su/alb-mus/5524387-460x460/landscapes.jpg
#         1/18 Is She In Love With Love?
#         Status code: 200 and took 0:00:00.38799
#         http://tut-audio.su/download-music/11222668/the-scene-is-she-in-love-with-love.mp3
#         2/18 Times Up
#         Status code: 200 and took 0:00:00.60893
#         http://tut-audio.su/download-music/11222669/007-times-up.mp3
#         3/18 Can You See Me
#         Status code: 200 and took 0:00:00.63895
#         http://tut-audio.su/download-music/11222670/007-can-you-see-me.mp3
#         4/18 Day That I Met You
#         Status code: 200 and took 0:00:00.41829
#         http://tut-audio.su/download-music/11222671/the-scene-day-that-i-met-you.mp3
#         5/18 Something That You Said
#         Status code: 200 and took 0:00:00.46427
#         http://tut-audio.su/download-music/11222672/the-scene-something-that-you-said.mp3
#         6/18 Show My Love
#         Status code: 200 and took 0:00:02.85807
#         http://tut-audio.su/download-music/11222673/the-scene-show-my-love.mp3
#         7/18 The Realisation
#         Status code: 200 and took 0:00:00.49335
#         http://tut-audio.su/download-music/11222674/the-scene-the-realisation.mp3
#         8/18 Gimme Some Lovin'
#         Status code: 200 and took 0:00:00.51436
#         http://tut-audio.su/download-music/11222675/007-gimme-some-lovin.mp3
#         9/18 Nearly Man
#         Status code: 200 and took 0:00:00.44931
#         http://tut-audio.su/download-music/11222676/007-nearly-man.mp3
#         10/18 Now I Know
#         Status code: 200 and took 0:00:00.75453
#         http://tut-audio.su/download-music/11222677/007-now-i-know.mp3
#         11/18 Cover Girl
#         Status code: 200 and took 0:00:00.64345
#         http://tut-audio.su/download-music/11222678/007-cover-girl.mp3
#         12/18 Good Lovin'
#         Status code: 200 and took 0:00:00.39428
#         http://tut-audio.su/download-music/11222679/the-scene-good-lovin.mp3
#         13/18 Looking For Love
#         Status code: 200 and took 0:00:00.55939
#         http://tut-audio.su/download-music/11222680/the-scene-looking-for-love.mp3
#         14/18 Bitter About Love
#         Status code: 200 and took 0:00:00.43330
#         http://tut-audio.su/download-music/11222681/007-bitter-about-love.mp3
#         15/18 She'll Come My Way
#         Status code: 200 and took 0:00:00.95126
#         http://tut-audio.su/download-music/11222682/007-she-ll-come-my-way.mp3
#         16/18 Shake On Down
#         Status code: 200 and took 0:00:00.70049
#         http://tut-audio.su/download-music/11222683/the-scene-shake-on-down.mp3
#         17/18 Stop Go
#         Status code: 200 and took 0:00:00.43030
#         http://tut-audio.su/download-music/11222684/the-scene-stop-go.mp3
#         18/18 Tin Cans
#         Status code: 200 and took 0:00:00.42771
#         http://tut-audio.su/download-music/11222685/the-scene-tin-cans.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 18, Timeouts: []
#
#   Found: http://tut-audio.su/mp3-album-007-james-bond-50-years-download-5443165.html (21)
#    New Artist London Symphony Orchestra added to data base!
#    This album has been added to the data base:
#      Artist: London Symphony Orchestra
#      Album name: 007 James Bond 50 Years
#      Year:
#      Cover: http://tut-audio.su/alb-mus/5443165-460x460/007-james-bond-50-years.jpg
#         1/39 Thunderball
#         Status code: 200 and took 0:00:00.62477
#         http://tut-audio.su/download-music/6184972/london-symphony-orchestra-thunderball.mp3
#         2/39 Goldfinger
#         Status code: 200 and took 0:00:00.38084
#         http://tut-audio.su/download-music/6184973/london-symphony-orchestra-goldfinger.mp3
#         3/39 You Only Live Twice
#         Status code: 200 and took 0:00:00.46952
#         http://tut-audio.su/download-music/6184974/london-symphony-orchestra-you-only-live-twice.mp3
#         4/39 The Man With The Golden Gun
#         Status code: 200 and took 0:00:00.36826
#         http://tut-audio.su/download-music/6184975/london-symphony-orchestra-the-man-with-the-golden-gun.mp3
#         5/39 Live And Let Die
#         Status code: 200 and took 0:00:00.44731
#         http://tut-audio.su/download-music/6184976/london-symphony-orchestra-live-and-let-die.mp3
#         6/39 For Your Eyes Only
#         Status code: 200 and took 0:00:00.40450
#         http://tut-audio.su/download-music/6184977/london-symphony-orchestra-for-your-eyes-only.mp3
#         7/39 From Russia With Love
#         Status code: 200 and took 0:00:00.60242
#         http://tut-audio.su/download-music/6184978/london-symphony-orchestra-from-russia-with-love.mp3
#         8/39 Nobody Does It Better (The Spy Who Loved Me)
#         Status code: 200 and took 0:00:00.41529
#         http://tut-audio.su/download-music/6184979/london-symphony-orchestra-nobody-does-it-better-the-spy-who-loved-me.mp3
#         9/39 On Her Majesty's Secret Service
#         Status code: 200 and took 0:00:00.69213
#         http://tut-audio.su/download-music/6184981/london-symphony-orchestra-on-her-majesty-s-secret-service.mp3
#         10/39 Moonraker
#         Status code: 200 and took 0:00:00.45331
#         http://tut-audio.su/download-music/6184982/london-symphony-orchestra-moonraker.mp3
#         11/39 Diamonds Are Forever
#         Status code: 200 and took 0:00:00.48634
#         http://tut-audio.su/download-music/6184983/london-symphony-orchestra-diamonds-are-forever.mp3
#         12/39 James Bond Theme (Reprise)
#         Status code: 200 and took 0:00:00.41880
#         http://tut-audio.su/download-music/6184985/london-symphony-orchestra-james-bond-theme-reprise.mp3
#         13/39 All Time High (Octopussy)
#         Status code: 200 and took 0:00:00.44431
#         http://tut-audio.su/download-music/6184986/london-symphony-orchestra-all-time-high-octopussy.mp3
#         14/39 Die Another Day
#         Status code: 200 and took 0:00:00.66940
#         http://tut-audio.su/download-music/7631929/the-popstar-band-die-another-day.mp3
#         15/39 Goldfinger "Cocktail Mix 2"
#         Status code: 200 and took 0:00:00.58141
#         http://tut-audio.su/download-music/7962213/the-popcorn-orchestra-goldfinger-cocktail-mix-2.mp3
#         16/39 Goldfinger "Cocktail Mix 1"
#         Status code: 200 and took 0:00:00.53878
#         http://tut-audio.su/download-music/7972501/the-popcorn-orchestra-goldfinger-cocktail-mix-1.mp3
#         17/39 The World Is Not Enough (007, James Bond, The World Is Not Enough)
#         Status code: 200 and took 0:00:00.47033
#         http://tut-audio.su/download-music/8174843/the-popstar-band-the-world-is-not-enough-007-james-bond-the-world-is-not-enough.mp3
#         18/39 Live And Let Die
#         Status code: 200 and took 0:00:00.42129
#         http://tut-audio.su/download-music/8215725/the-popstar-band-live-and-let-die.mp3
#         19/39 Licence To Kill (Licence To Kill 1989)
#         Status code: 200 and took 0:00:00.46232
#         http://tut-audio.su/download-music/8215726/the-popstar-band-licence-to-kill-licence-to-kill-1989.mp3
#         20/39 Moonraker Main Title (Moonraker 1979)
#         Status code: 200 and took 0:00:00.38827
#         http://tut-audio.su/download-music/8215727/the-popstar-band-moonraker-main-title-moonraker-1979.mp3
#         21/39 For Your Eyes Only (For Your Eyes Only 1981)
#         Status code: 200 and took 0:00:00.44531
#         http://tut-audio.su/download-music/8215728/the-popstar-band-for-your-eyes-only-for-your-eyes-only-1981.mp3
#         22/39 The Living Daylights (The Living Daylights 1987)
#         Status code: 200 and took 0:00:00.81242
#         http://tut-audio.su/download-music/8215729/the-popstar-band-the-living-daylights-the-living-daylights-1987.mp3
#         23/39 All Time High (Octopussy 1983)
#         Status code: 200 and took 0:00:00.43240
#         http://tut-audio.su/download-music/8215730/the-popstar-band-all-time-high-octopussy-1983.mp3
#         24/39 James Bond Theme
#         Status code: 200 and took 0:00:00.44431
#         http://tut-audio.su/download-music/10410653/the-hollywood-strings-james-bond-theme.mp3
#         25/39 Tomorrow Never Dies (From "Tomorrow Never Dies")
#         Status code: 200 and took 0:00:01.03173
#         http://tut-audio.su/download-music/10410796/the-popstar-band-tomorrow-never-dies-from-tomorrow-never-dies.mp3
#         26/39 You Only Live Twice
#         Status code: 200 and took 0:00:00.66213
#         http://tut-audio.su/download-music/10410797/the-popstar-band-you-only-live-twice.mp3
#         27/39 Belle of Chicago (From "Octopussy")
#         Status code: 200 and took 0:00:00.42608
#         http://tut-audio.su/download-music/10410798/usa-patriots-band-belle-of-chicago-from-octopussy.mp3
#         28/39 Diamonds Are Forever (From "Diamonds Are Forever")
#         Status code: 200 and took 0:00:00.35079
#         http://tut-audio.su/download-music/10410799/the-popstar-band-diamonds-are-forever-from-diamonds-are-forever.mp3
#         29/39 The Liberty Bell (From "Octopussy")
#         Status code: 200 and took 0:00:00.46929
#         http://tut-audio.su/download-music/10410800/usa-patriots-band-the-liberty-bell-from-octopussy.mp3
#         30/39 Live and Let Die
#         Status code: 200 and took 0:00:00.42735
#         http://tut-audio.su/download-music/10410801/the-new-synthesizer-experience-live-and-let-die.mp3
#         31/39 From Russia With Love (From "From Russia With Love")
#         Status code: 200 and took 0:00:01.07653
#         http://tut-audio.su/download-music/10410802/the-popstar-band-from-russia-with-love-from-from-russia-with-love.mp3
#         32/39 Goldfinger (From "Goldfinger")
#         Status code: 200 and took 0:00:00.75954
#         http://tut-audio.su/download-music/10410804/the-hollywood-strings-goldfinger-from-goldfinger.mp3
#         33/39 Another Way to Die (From "Quantum of Solace")
#         Status code: 200 and took 0:00:00.51781
#         http://tut-audio.su/download-music/10410805/the-popstar-band-another-way-to-die-from-quantum-of-solace.mp3
#         34/39 Goldfinger (From "Goldfinger")
#         Status code: 200 and took 0:00:01.09495
#         http://tut-audio.su/download-music/10410806/the-popstar-band-goldfinger-from-goldfinger.mp3
#         35/39 A View to a Kill (From "A View to a Kill")
#         Status code: 200 and took 0:00:00.70437
#         http://tut-audio.su/download-music/10410807/the-popstar-band-a-view-to-a-kill-from-a-view-to-a-kill.mp3
#         36/39 The Living Daylights (From "The Living Daylights")
#         Status code: 200 and took 0:00:00.33451
#         http://tut-audio.su/download-music/10410808/the-new-synthesizer-experience-the-living-daylights-from-the-living-daylights.mp3
#         37/39 Thunderball (From "Thunderball")
#         Status code: 200 and took 0:00:00.36884
#         http://tut-audio.su/download-music/10410809/the-popstar-band-thunderball-from-thunderball.mp3
#         38/39 It Had to Be You (From "Tomorrow Never Dies")
#         Status code: 200 and took 0:00:01.32444
#         http://tut-audio.su/download-music/10410810/the-popstar-band-it-had-to-be-you-from-tomorrow-never-dies.mp3
#         39/39 You Only Live Twice
#         Status code: 200 and took 0:00:00.38827
#         http://tut-audio.su/download-music/10410811/the-new-synthesizer-experience-you-only-live-twice.mp3
# -------------------------------------------------------------------------------------------
# Missing: 0, Live: 39, Timeouts: []
#
#  Try No. 2
#  Try No. 3
#  Try No. 4
#  Try No. 5
#  Try No. 6
#  Try No. 7
#  Try No. 8
#  Try No. 9
# -------------------------------------------------------------------------------------------
# Added 21 Albums to the database of 007-man
# -------------------------------------------------------------------------------------------
# Ended at Mon, 05 Feb 2018 21:44:27 +0000, so needed 0:05:58.490740
# Artists added to data base: 20
# Albums added to data base: 21
# Tracks added to data base: 353
# Missing tracks: 9
# Connection errors: 0
# Timeouts: 0

# %%
<div class="player" data-mp3url="/download-music/7799163/moskwa-tv-the-shelter-of-love-91-recording.mp3" data-title="Moskwa TV — The Shelter Of Love ('91-Recording)">
<div class="controls">
<a href="javascript:void(0);" onclick="play_audio(this);return false;"><img alt="listen Moskwa TV — The Shelter Of Love ('91-Recording)" src="/Theme/Images/play_button.png"/></a>
<a href="/download-music/7799163/moskwa-tv-the-shelter-of-love-91-recording.mp3" onclick="window.open(this.href, '', 'scrollbars=1');  return false; " target="_blank"><img alt="download Moskwa TV — The Shelter Of Love ('91-Recording)" src="/Theme/Images/download_button.png"/></a>
<img alt="download Moskwa TV — The Shelter Of Love ('91-Recording)" class="album-img" src="/alb-mus/0-50x50/default.jpg"/>
</div>
<div class="track-info">
<span class="track-title">Moskwa TV — The Shelter Of Love ('91-Recording)</span>
</div>
</div>

# %%
categories
# Out:
# [{'name': '0,33 ml', 'url': '/music-file/0-33-ml'},
#  {'name': '091', 'url': '/music-file/091'},
#  {'name': '03', 'url': '/music-file/03'},
#  {'name': '08001', 'url': '/music-file/08001'},
#  {'name': '0:00', 'url': '/music-file/0-00'},
#  {'name': '000', 'url': '/music-file/000'},
#  {'name': '02 (feat. Рожден)', 'url': '/music-file/02-feat-рожден'},
#  {'name': '0', 'url': '/music-file/0'},
#  {'name': '00', 'url': '/music-file/00'},
#  {'name': '010', 'url': '/music-file/010'},
#  {'name': '0DBFS', 'url': '/music-file/0dbfs'},
#  {'name': '05001', 'url': '/music-file/05001'},
#  {'name': '0.7277777777777777', 'url': '/music-file/0-7277777777777777'},
#  {'name': '007 Man', 'url': '/music-file/007-man'},
#  {'name': '01', 'url': '/music-file/01'},
#  {'name': '02', 'url': '/music-file/02'},
#  {'name': '08für10', 'url': '/music-file/08für10'},
#  {'name': '0102', 'url': '/music-file/0102'},
#  {'name': '0101', 'url': '/music-file/0101'},
#  {'name': '01-N', 'url': '/music-file/01-n'},
#  {'name': '01-N vs Auroride', 'url': '/music-file/01-n-vs-auroride'},
#  {'name': '0.4', 'url': '/music-file/0-4'},
#  {'name': '01N', 'url': '/music-file/01n'},
#  {'name': '0SM', 'url': '/music-file/0sm'},
#  {'name': '0x1dy', 'url': '/music-file/0x1dy'},
#  {'name': '0dbs', 'url': '/music-file/0dbs'},
#  {'name': '06R', 'url': '/music-file/06r'},
#  {'name': '007 Lovers', 'url': '/music-file/007-lovers'},
#  {'name': '00Zicky', 'url': '/music-file/00zicky'},
#  {'name': '015B', 'url': '/music-file/015b'},
#  {'name': '099 Mafia', 'url': '/music-file/099-mafia'},
#  {'name': '007 Band', 'url': '/music-file/007-band'},
#  {'name': '0800', 'url': '/music-file/0800'},
#  {'name': '09 Ampere', 'url': '/music-file/09-ampere'},
#  {'name': '007 Collective', 'url': '/music-file/007-collective'},
#  {'name': '0547', 'url': '/music-file/0547'},
#  {'name': '099', 'url': '/music-file/099'},
#  {'name': '08Hotel', 'url': '/music-file/08hotel'},
#  {'name': '007', 'url': '/music-file/007'},
#  {'name': '08 Hotel', 'url': '/music-file/08-hotel'},
#  {'name': '0-JAY', 'url': '/music-file/0-jay'},
#  {'name': '0.99', 'url': '/music-file/0-99'},
#  {'name': '0=0', 'url': '/music-file/00'},
#  {'name': '007 In Heaven', 'url': '/music-file/007-in-heaven'},
#  {'name': '007 Hundred Club', 'url': '/music-file/007-hundred-club'},
#  {'name': '0.8Syooogeki', 'url': '/music-file/0-8syooogeki'},
#  {'name': '0131', 'url': '/music-file/0131'},
#  {'name': '007 Players', 'url': '/music-file/007-players'},
#  {'name': '02386393Glamma Kid', 'url': '/music-file/02386393glamma-kid'},
#  {'name': '0 Soul 7', 'url': '/music-file/0-soul-7'},
#  {'name': '040', 'url': '/music-file/040'},
#  {'name': '09:31 PM', 'url': '/music-file/09-31-pm'},
#  {'name': '0:28', 'url': '/music-file/0-28'},
#  {'name': '00 Spies', 'url': '/music-file/00-spies'},
#  {'name': '00.db', 'url': '/music-file/00-db'},
#  {'name': '01 - N', 'url': '/music-file/01-n'},
#  {'name': '0 0 0', 'url': '/music-file/0-0-0'},
#  {'name': '0131 vs Dj Dstar', 'url': '/music-file/0131-vs-dj-dstar'},
#  {'name': '007 Orchestra', 'url': '/music-file/007-orchestra'},
#  {'name': '073 SiDERZ & 9 PRODUCT', 'url': '/music-file/073-siderz-9-product'},
#  {'name': '0x7f', 'url': '/music-file/0x7f'},
#  {'name': '006', 'url': '/music-file/006'},
#  {'name': '03_JTT004_3__HEY_SAM_.wav',
#   'url': '/music-file/03-jtt004-3-hey-sam-wav'},
#  {'name': '00tz 00tz', 'url': '/music-file/00tz-00tz'},
#  {'name': '0+1=everything', 'url': '/music-file/0-1everything'},
#  {'name': '0mnis0und', 'url': '/music-file/0mnis0und'},
#  {'name': '0mni S0und', 'url': '/music-file/0mni-s0und'},
#  {'name': '0Dark30', 'url': '/music-file/0dark30'},
#  {'name': '08/15', 'url': '/music-file/08-15'},
#  {'name': '007 & Belle', 'url': '/music-file/007-belle'},
#  {'name': '0CD', 'url': '/music-file/0cd'},
#  {'name': '0bsrvr', 'url': '/music-file/0bsrvr'},
#  {'name': '05K4R', 'url': '/music-file/05k4r'},
#  {'name': '03 Tha Hu$tla', 'url': '/music-file/03-tha-hutla'},
#  {'name': '0337', 'url': '/music-file/0337'},
#  {'name': '00 Crimzen', 'url': '/music-file/00-crimzen'},
#  {'name': '04. Sunny Lax - Marvel', 'url': '/music-file/04-sunny-lax-marvel'},
#  {'name': '03 Tha Hustla', 'url': '/music-file/03-tha-hustla'},
#  {'name': '0matt0', 'url': '/music-file/0matt0'},
#  {'name': '03tha Hu$tla & J-Dawg', 'url': '/music-file/03tha-hutla-j-dawg'},
#  {'name': '08trio', 'url': '/music-file/08trio'},
#  {'name': '03 Alexander Popov - Legend',
#   'url': '/music-file/03-alexander-popov-legend'},
#  {'name': '051 Connexion', 'url': '/music-file/051-connexion'},
#  {'name': '01 Band', 'url': '/music-file/01-band'},
#  {'name': '04LM', 'url': '/music-file/04lm'},
#  {'name': '0bey Meh', 'url': '/music-file/0bey-meh'},
#  {'name': '007 aka James Bond', 'url': '/music-file/007-aka-james-bond'},
#  {'name': '0rchestre Conga Succès',
#   'url': '/music-file/0rchestre-conga-succès'},
#  {'name': '0700', 'url': '/music-file/0700'},
#  {'name': '013', 'url': '/music-file/013'},
#  {'name': '01e-Motion', 'url': '/music-file/01e-motion'},
#  {'name': '05 Lush & Simon feat. XOV - City Of Lights (Official Radio Mix)',
#   'url': '/music-file/05-lush-simon-feat-xov-city-of-lights-official-radio-mix'},
#  {'name': '0 Kopia', 'url': '/music-file/0-kopia'},
#  {'name': '01 (Pop Music)', 'url': '/music-file/01-pop-music'},
#  {'name': '0vrcast', 'url': '/music-file/0vrcast'},
#  {'name': '0kill', 'url': '/music-file/0kill'},
#  {'name': '0DB', 'url': '/music-file/0db'},
#  {'name': '01 N', 'url': '/music-file/01-n'},
#  {'name': '0000', 'url': '/music-file/0000'},
#  {'name': '0re0', 'url': '/music-file/0re0'},
#  {'name': '009 Sound System', 'url': '/music-file/009-sound-system'},
#  {'name': '080', 'url': '/music-file/080'},
#  {'name': '007 de Petit Pays', 'url': '/music-file/007-de-petit-pays'},
#  {'name': '0Yal', 'url': '/music-file/0yal'},
#  {'name': '070 Shake', 'url': '/music-file/070-shake'},
#  {'name': '070 Phi', 'url': '/music-file/070-phi'},
#  {'name': '070 Razsy Beats', 'url': '/music-file/070-razsy-beats'},
#  {'name': '070', 'url': '/music-file/070'},
#  {'name': '0rbiterred', 'url': '/music-file/0rbiterred'},
#  {'name': '044 Роузи', 'url': '/music-file/044-роузи'}]

# %%
session.query(func.count(Artist.id)).scalar() #.all()
# Out:
# 2

# %%
session.query(Artist).all()[0].albums[0].tracks[0].album.artist.name
# Out:
# '08001'

# %%
session.query(Album).all()[3].verbose()
# Out:
# Name: Cinemagic 27
# Artist: Marc Reift
# Year: 2013
# URL: http://tut-audio.su/mp3-album-cinemagic-27-download-5868980.html
# Cover URL: http://tut-audio.su/alb-mus/5868980-460x460/cinemagic-27.jpg
# ID: 4

# %%
session.query(func.count(Album.id)).scalar()
# Out:
# 3

# %%
session.query(Album).all()[0].verbose()
# Out:
# Name: 80:01 - Single
# Artist: eightykidz
# Year: 2013
# Number of tracks: 3
# Number of live tracks: 3
# URL: http://tut-audio.su/mp3-album-80-01-single-download-5990721.html
# Cover URL: http://tut-audio.su/alb-mus/5990721-460x460/80-01-single.jpg
# ID: 1

# %%
tw.indent('Hello', ' ')
# Out:
# ' Hello'

# %%
file = requests.head('http://tut-audio.su/download-music/16210129/hyphy-instrumentals-hyphy-instrumentals-139.mp3')

# %%
file.headers
# Out:
# {'Date': 'Mon, 05 Feb 2018 23:41:05 GMT', 'Content-Type': 'audio/mpeg', 'Content-Length': '6796015', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dca53a6ab1acf7f2b1192022508e90bdc1517874065; expires=Tue, 05-Feb-19 23:41:05 GMT; path=/; domain=.tut-audio.su; HttpOnly', 'Cache-Control': 'private', 'Last-Modified': 'Mon, 05 Feb 2018 17:06:57 GMT', 'Accept-Ranges': 'bytes,bytes', 'Access-Control-Allow-Origin': '*', 'Content-Disposition': 'attachment; filename=hyphy-instrumentals-hyphy-instrumentals-139.mp3', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Server': 'cloudflare', 'CF-RAY': '3e89b7ea77034112-HAM'}

# %%
import json

# %%
print(json.dumps(file.headers, sort_keys=True, indent=4, default=str))
# Out:
# "{'Date': 'Mon, 05 Feb 2018 23:41:05 GMT', 'Content-Type': 'audio/mpeg', 'Content-Length': '6796015', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dca53a6ab1acf7f2b1192022508e90bdc1517874065; expires=Tue, 05-Feb-19 23:41:05 GMT; path=/; domain=.tut-audio.su; HttpOnly', 'Cache-Control': 'private', 'Last-Modified': 'Mon, 05 Feb 2018 17:06:57 GMT', 'Accept-Ranges': 'bytes,bytes', 'Access-Control-Allow-Origin': '*', 'Content-Disposition': 'attachment; filename=hyphy-instrumentals-hyphy-instrumentals-139.mp3', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Server': 'cloudflare', 'CF-RAY': '3e89b7ea77034112-HAM'}"
